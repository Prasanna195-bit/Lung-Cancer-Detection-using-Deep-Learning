# %% [markdown]
# # LUNG CANCER DETECTION

# %%
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.metrics import categorical_accuracy,categorical_crossentropy, top_k_categorical_accuracy
from keras import backend as k
from keras.layers.convolutional import*
import os
import tensorflow as tf
import random as rn
from matplotlib import pyplot as plt
import itertools
from keras.models import Model
import matplotlib.pyplot as plt
from keras.optimizers import Adam,RMSprop
# %matplotlib inline
import json
# Out:
# Using TensorFlow backend.

# %%
tf.keras.backend.clear_session()

# %%
#CREATING VARIABLES AND ASSIGNING PATH
train_path='D:/Pre-processing/dicomimages/train'
valid_path='D:/Pre-processing/dicomimages/valid'
test_path='D:/Pre-processing/dicomimages/test'

# %%
train_batches=ImageDataGenerator().flow_from_directory(train_path,target_size=(224,224),classes=['0','1'],batch_size=10)
valid_batches=ImageDataGenerator().flow_from_directory(valid_path,target_size=(224,224),classes=['00','11'],batch_size=10)
test_batches=ImageDataGenerator().flow_from_directory(test_path,target_size=(224,224),classes=['test1'],batch_size=1)
# Out:
# Found 1660 images belonging to 2 classes.
# Found 314 images belonging to 2 classes.
# Found 2 images belonging to 1 classes.

# %%
#FUNCTION TO DISPLAY THE IMAGES
#plot image with labels
def plots(ims,figsize=(12,6),rows=1,interp=False,titles=None):
    if type(ims[0]) is np.ndarray:
        ims=np.array(ims).astype(np.uint8)
        if(ims.shape[-1]!=3):
            ims=ims.transpose((0,2,3,1))
    f=plt.figure(figsize=figsize)
    cols=len(ims)//rows if len(ims) %2==0 else len(ims)//rows+1
    for i in range(len(ims)):
        sp=f.add_subplot(rows,cols,i+1)
        sp.axis('off')
        if titles is not None:
            sp.set_title(titles[i],fontsize=16)
        plt.imshow(ims[i],cmap="CMRmap",interpolation=None if interp else 'none')

# %%
imgs,labels=next(train_batches)

# %%
#we call the function plot to display images
print("FEW IMAGES OF TRAINING DATASET")
plots(imgs, titles=labels)
# Out:
# FEW IMAGES OF TRAINING DATASET

# %%
import time

class TimeHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, epoch, logs={}):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, epoch, logs={}):
        self.times.append(time.time() - self.epoch_time_start)

# %%
time_callback = TimeHistory()

# %%
import json
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard

# %%
from tensorflow.keras.applications.vgg16 import VGG16

# %%
from tensorflow.keras import layers

# %%
base_model = VGG16(input_shape = (224, 224, 3), # Shape of our images
include_top = False, # Leave out the last fully connected layer
weights = 'imagenet')

# %%
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
# Flatten the output layer to 1 dimension
x = layers.Flatten()(base_model.output)

# Add a fully connected layer with 512 hidden units and ReLU activation
x = layers.Dense(512, activation='relu')(x)

# Add a dropout rate of 0.5
x = layers.Dropout(0.5)(x)

# Add a final sigmoid layer for classification
x = layers.Dense(2, activation='softmax')(x)

# %%
model = tf.keras.models.Model(base_model.input, x)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               12845568
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 27,561,282
# Trainable params: 12,846,594
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
model.compile(tf.keras.optimizers.Adam(lr=.0001),loss='binary_crossentropy',metrics=['accuracy'])

# %%
tf.keras.backend.clear_session()

# %%
learn_control = ReduceLROnPlateau(monitor='val_accuracy', patience=2,
                                  verbose=1,factor=0.2)

filepath="VGG16_NoSegment_weights_best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

history= model.fit(train_batches, steps_per_epoch=166,
                              validation_data=valid_batches,validation_steps=31,epochs=20,verbose=1,
                              callbacks=[learn_control, checkpoint,time_callback]
)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 166 steps, validate for 31 steps
# Epoch 1/20
# 165/166 [============================>.] - ETA: 0s - loss: 2.6962 - accuracy: 0.8036
# Epoch 00001: val_accuracy improved from -inf to 0.82581, saving model to VGG16_NoSegment_weights_best.hdf5
# 166/166 [==============================] - 27s 166ms/step - loss: 2.6800 - accuracy: 0.8048 - val_loss: 2.4204 - val_accuracy: 0.8258
# Epoch 2/20
# 165/166 [============================>.] - ETA: 0s - loss: 0.3950 - accuracy: 0.9679
# Epoch 00002: val_accuracy did not improve from 0.82581
# 166/166 [==============================] - 25s 153ms/step - loss: 0.3927 - accuracy: 0.9681 - val_loss: 2.5580 - val_accuracy: 0.8226
# Epoch 3/20
# 165/166 [============================>.] - ETA: 0s - loss: 0.3411 - accuracy: 0.9715
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 00003: val_accuracy did not improve from 0.82581
# 166/166 [==============================] - 26s 154ms/step - loss: 0.3391 - accuracy: 0.9717 - val_loss: 2.9879 - val_accuracy: 0.7871
# Epoch 4/20
# 165/166 [============================>.] - ETA: 0s - loss: 0.1183 - accuracy: 0.9873
# Epoch 00004: val_accuracy did not improve from 0.82581
# 166/166 [==============================] - 26s 154ms/step - loss: 0.1176 - accuracy: 0.9873 - val_loss: 2.7522 - val_accuracy: 0.8161
# Epoch 5/20
# 165/166 [============================>.] - ETA: 0s - loss: 0.0098 - accuracy: 0.9976
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
#
# Epoch 00005: val_accuracy did not improve from 0.82581
# 166/166 [==============================] - 26s 155ms/step - loss: 0.0097 - accuracy: 0.9976 - val_loss: 2.7484 - val_accuracy: 0.8129
# Epoch 6/20
# 165/166 [============================>.] - ETA: 0s - loss: 0.0547 - accuracy: 0.9958
# Epoch 00006: val_accuracy did not improve from 0.82581
# 166/166 [==============================] - 26s 155ms/step - loss: 0.0543 - accuracy: 0.9958 - val_loss: 2.7931 - val_accuracy: 0.8097
# Epoch 7/20
# 165/166 [============================>.] - ETA: 0s - loss: 0.0213 - accuracy: 0.9982
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
#
# Epoch 00007: val_accuracy did not improve from 0.82581
# 166/166 [==============================] - 26s 155ms/step - loss: 0.0216 - accuracy: 0.9976 - val_loss: 2.7898 - val_accuracy: 0.8129
# Epoch 8/20
# 165/166 [============================>.] - ETA: 0s - loss: 0.0227 - accuracy: 0.9982
# Epoch 00008: val_accuracy did not improve from 0.82581
# 166/166 [==============================] - 26s 155ms/step - loss: 0.0225 - accuracy: 0.9982 - val_loss: 2.7867 - val_accuracy: 0.8129
# Epoch 9/20
# 165/166 [============================>.] - ETA: 0s - loss: 0.0194 - accuracy: 0.9982
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
#
# Epoch 00009: val_accuracy did not improve from 0.82581
# 166/166 [==============================] - 26s 155ms/step - loss: 0.0192 - accuracy: 0.9982 - val_loss: 2.7831 - val_accuracy: 0.8129
# Epoch 10/20
# 165/166 [============================>.] - ETA: 0s - loss: 0.0184 - accuracy: 0.9982
# Epoch 00010: val_accuracy did not improve from 0.82581
# 166/166 [==============================] - 26s 155ms/step - loss: 0.0183 - accuracy: 0.9982 - val_loss: 2.7828 - val_accuracy: 0.8129
# Epoch 11/20
# 165/166 [============================>.] - ETA: 0s - loss: 0.0203 - accuracy: 0.9982
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 3.199999980552093e-08.
#
# Epoch 00011: val_accuracy did not improve from 0.82581
# 166/166 [==============================] - 26s 156ms/step - loss: 0.0202 - accuracy: 0.9982 - val_loss: 2.7823 - val_accuracy: 0.8129
# Epoch 12/20
# 165/166 [============================>.] - ETA: 0s - loss: 0.0334 - accuracy: 0.9976
# Epoch 00012: val_accuracy did not improve from 0.82581
# 166/166 [==============================] - 26s 156ms/step - loss: 0.0332 - accuracy: 0.9976 - val_loss: 2.7822 - val_accuracy: 0.8129
# Epoch 13/20
# 165/166 [============================>.] - ETA: 0s - loss: 0.0065 - accuracy: 0.9994
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 6.399999818995639e-09.
#
# Epoch 00013: val_accuracy did not improve from 0.82581
# 166/166 [==============================] - 26s 156ms/step - loss: 0.0065 - accuracy: 0.9994 - val_loss: 2.7820 - val_accuracy: 0.8129
# Epoch 14/20
# 165/166 [============================>.] - ETA: 0s - loss: 0.0228 - accuracy: 0.9982
# Epoch 00014: val_accuracy did not improve from 0.82581
# 166/166 [==============================] - 26s 156ms/step - loss: 0.0227 - accuracy: 0.9982 - val_loss: 2.7820 - val_accuracy: 0.8129
# Epoch 15/20
# 165/166 [============================>.] - ETA: 0s - loss: 0.0128 - accuracy: 0.9988
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1.279999928271991e-09.
#
# Epoch 00015: val_accuracy did not improve from 0.82581
# 166/166 [==============================] - 26s 156ms/step - loss: 0.0127 - accuracy: 0.9988 - val_loss: 2.7821 - val_accuracy: 0.8129
# Epoch 16/20
# 165/166 [============================>.] - ETA: 0s - loss: 0.0368 - accuracy: 0.9970
# Epoch 00016: val_accuracy did not improve from 0.82581
# 166/166 [==============================] - 26s 156ms/step - loss: 0.0366 - accuracy: 0.9970 - val_loss: 2.7821 - val_accuracy: 0.8129
# Epoch 17/20
# 165/166 [============================>.] - ETA: 0s - loss: 0.0204 - accuracy: 0.9982
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 2.55999976772614e-10.
#
# Epoch 00017: val_accuracy did not improve from 0.82581
# 166/166 [==============================] - 26s 156ms/step - loss: 0.0203 - accuracy: 0.9982 - val_loss: 2.7821 - val_accuracy: 0.8129
# Epoch 18/20
# 165/166 [============================>.] - ETA: 0s - loss: 0.0407 - accuracy: 0.9964
# Epoch 00018: val_accuracy did not improve from 0.82581
# 166/166 [==============================] - 26s 156ms/step - loss: 0.0404 - accuracy: 0.9964 - val_loss: 2.7821 - val_accuracy: 0.8129
# Epoch 19/20
# 165/166 [============================>.] - ETA: 0s - loss: 0.0416 - accuracy: 0.9970
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 5.119999424429978e-11.
#
# Epoch 00019: val_accuracy did not improve from 0.82581
# 166/166 [==============================] - 26s 156ms/step - loss: 0.0413 - accuracy: 0.9970 - val_loss: 2.7821 - val_accuracy: 0.8129
# Epoch 20/20
# 165/166 [============================>.] - ETA: 0s - loss: 0.0189 - accuracy: 0.9982
# Epoch 00020: val_accuracy did not improve from 0.82581
# 166/166 [==============================] - 26s 157ms/step - loss: 0.0187 - accuracy: 0.9982 - val_loss: 2.7821 - val_accuracy: 0.8129

# %%
sum(time_callback.times)
# Out:
# 517.549322605133
